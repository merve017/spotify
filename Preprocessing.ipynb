# %% [markdown]
# # Preprocessing

# %%
import os
import pandas as pd
import numpy as np
import json
import spotipy
import spotipy.oauth2 as oauth2
from spotipy.oauth2 import SpotifyOAuth,SpotifyClientCredentials
import yaml
import re
from tqdm import tqdm
import multiprocessing as mp
import time
import random
import datetime

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read data

# %%
def read_data():
     global df_artists  
     df_artists = pd.read_csv('data/spotify_artists.csv', sep=',') 
     global df_tracks
     df_tracks = pd.read_csv('data/spotify_tracks.csv', sep=',')

read_data()

# %% [markdown]
# ## Merging all dataframes

# %%
def transform_data():
    df_tracks['artists_id'] = df_tracks['artists_id'].str.strip("[]").str.replace("'","")
    df_tracks.rename(columns={'id':'tracks_id'}, inplace=True)
    df_tracks.rename(columns={'name':'tracks_name'}, inplace=True)
    #df_artists['genres'] = df_artists['genres'].apply(lambda x: x if x=="['']" else ["Unknown"])
    #df_artists.rename(columns={'id':'artists_id'}, inplace=True)
    df_artists['id'] = df_artists['id'].str.strip("[]").str.replace("'","")
    df_artists.rename(columns={'name':'artists_name'}, inplace=True)
    #df_artists['genres'] = df_artists['genres'].str.strip("[]").str.replace("'","")
    # Merge both dataframes
    global df_artists_tracks
    df_artists_tracks = pd.merge(df_tracks, df_artists, left_on='artists_id', right_on='id', how='inner')

transform_data()

# %%
pd.set_option('display.max_columns', None)
df_artists_tracks.head(5)
# Out:
#    Unnamed: 0_x  acousticness                album_id  \
# 0             0         0.294  0D3QufeCudpQANOR7luqdr
# 1         84077         0.166  3wIjGVauUxR4c3NvnQZ0Jo
# 2             1         0.863  1bcqsH5UyTBzmh9YizdsBE
# 3             6         0.824  51g5viCaYjOW5XO4qX1RCD
# 4            41         0.850  7EtGJVYZbb2Krgwizn2flB
#
#                                         analysis_url              artists_id  \
# 0  https://api.spotify.com/v1/audio-analysis/5qlj...  3mxJuHRn2ZWD5OofvJtDZY
# 1  https://api.spotify.com/v1/audio-analysis/3THT...  3mxJuHRn2ZWD5OofvJtDZY
# 2  https://api.spotify.com/v1/audio-analysis/3VAX...  4xWMewm6CYMstu0sPgd9jJ
# 3  https://api.spotify.com/v1/audio-analysis/1WJz...  4xWMewm6CYMstu0sPgd9jJ
# 4  https://api.spotify.com/v1/audio-analysis/65Mo...  4xWMewm6CYMstu0sPgd9jJ
#
#                                    available_markets country  danceability  \
# 0  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...      BE         0.698
# 1  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...      AR         0.543
# 2  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...      BE         0.719
# 3  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...      BE         0.688
# 4  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...      BE         0.632
#
#    disc_number  duration_ms  energy  \
# 0          1.0     235584.0   0.606
# 1          1.0     233998.0   0.612
# 2          1.0     656960.0   0.308
# 3          1.0      29240.0   0.304
# 4          1.0     497493.0   0.372
#
#                                                 href               tracks_id  \
# 0  https://api.spotify.com/v1/tracks/5qljLQuKnNJf...  5qljLQuKnNJf4F4vfxQB0V
# 1  https://api.spotify.com/v1/tracks/3THTkAwJOsmx...  3THTkAwJOsmxgizvYkBNRI
# 2  https://api.spotify.com/v1/tracks/3VAX2MJdmdqA...  3VAX2MJdmdqARLSU5hPMpm
# 3  https://api.spotify.com/v1/tracks/1WJzRtI1ABzV...  1WJzRtI1ABzV3TPIeJZVvi
# 4  https://api.spotify.com/v1/tracks/65MopnhsXOgY...  65MopnhsXOgYw4RuiA2pGU
#
#    instrumentalness   key  liveness  loudness  \
# 0          0.000003  10.0     0.151    -7.447
# 1          0.000000   9.0     0.129    -7.685
# 2          0.000000   6.0     0.253   -10.340
# 3          0.000000  10.0     0.142    -9.960
# 4          0.000000   7.0     0.110    -8.760
#
#                                               lyrics  mode  \
# 0  \r\n\r\nPerhaps I am bound to be restless\r\nA...   0.0
# 1  \r\n\r\nMuch better in my day\r\nMuch better i...   0.0
# 2  \r\nYour Gods and my Gods-do you or I know whi...   1.0
# 3  \r\nYour Gods and my Gods-do you or I know whi...   1.0
# 4  \r\nYour Gods and my Gods-do you or I know whi...   1.0
#
#                    tracks_name         playlist  popularity  \
# 0                        Blood  Hipsteribrunssi        28.0
# 1                      Jericho    Sideways 2019        37.0
# 2            The Ugly Duckling   Animal Stories        31.0
# 3             Three Blind Mice   Animal Stories         0.0
# 4  The Three Billy Goats Gruff   Animal Stories        30.0
#
#                                          preview_url  speechiness    tempo  \
# 0  https://p.scdn.co/mp3-preview/1b05a902da3a251d...       0.0262  115.018
# 1  https://p.scdn.co/mp3-preview/8af517b8202114d6...       0.0487  139.876
# 2  https://p.scdn.co/mp3-preview/d8140736a6131cb5...       0.9220  115.075
# 3  https://p.scdn.co/mp3-preview/54031f6d3ab4784a...       0.5310   77.056
# 4  https://p.scdn.co/mp3-preview/32c98e55e89da792...       0.9350   84.486
#
#    time_signature                                         track_href  \
# 0             4.0  https://api.spotify.com/v1/tracks/5qljLQuKnNJf...
# 1             3.0  https://api.spotify.com/v1/tracks/3THTkAwJOsmx...
# 2             3.0  https://api.spotify.com/v1/tracks/3VAX2MJdmdqA...
# 3             3.0  https://api.spotify.com/v1/tracks/1WJzRtI1ABzV...
# 4             4.0  https://api.spotify.com/v1/tracks/65MopnhsXOgY...
#
#   track_name_prev_x  track_number                                   uri  \
# 0          track_14           1.0  spotify:track:5qljLQuKnNJf4F4vfxQB0V
# 1          track_18           1.0  spotify:track:3THTkAwJOsmxgizvYkBNRI
# 2           track_3           3.0  spotify:track:3VAX2MJdmdqARLSU5hPMpm
# 3           track_9           2.0  spotify:track:1WJzRtI1ABzV3TPIeJZVvi
# 4          track_35           8.0  spotify:track:65MopnhsXOgYw4RuiA2pGU
#
#    valence type_x  Unnamed: 0_y  artist_popularity  followers  \
# 0    0.622  track         45499                 28        425
# 1    0.463  track         45499                 28        425
# 2    0.589  track          8219                 36       2965
# 3    0.414  track          8219                 36       2965
# 4    0.611  track          8219                 36       2965
#
#               genres                      id           artists_name  \
# 0  ['finnish indie']  3mxJuHRn2ZWD5OofvJtDZY           Jesse Markin
# 1  ['finnish indie']  3mxJuHRn2ZWD5OofvJtDZY           Jesse Markin
# 2                 []  4xWMewm6CYMstu0sPgd9jJ  Favorite Kids Stories
# 3                 []  4xWMewm6CYMstu0sPgd9jJ  Favorite Kids Stories
# 4                 []  4xWMewm6CYMstu0sPgd9jJ  Favorite Kids Stories
#
#                  track_id track_name_prev_y  type_y
# 0  3THTkAwJOsmxgizvYkBNRI          track_19  artist
# 1  3THTkAwJOsmxgizvYkBNRI          track_19  artist
# 2  3VAX2MJdmdqARLSU5hPMpm           track_5  artist
# 3  3VAX2MJdmdqARLSU5hPMpm           track_5  artist
# 4  3VAX2MJdmdqARLSU5hPMpm           track_5  artist

# %% [markdown]
# ## Selecting Columns

# %%
# acousticness, danceability, duration_ms, energy, instrumentalness, key, liveness, loudness, mode, popularity, speechiness, tempo, time_signature, valence, 
# album_id, artists_id, country, tracks_id, tracks_name (lyrics), 	uri, genre
# artist_popularity, followers 

#select all these attributes and drop the others

def drop_columns():
    global df_artists_tracks
    df_artists_tracks = df_artists_tracks[['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness', 
                        'loudness', 'mode', 'popularity', 'speechiness', 'tempo', 'time_signature', 'valence',
                        'artist_popularity', 'followers', 'genres', 'tracks_id', 'tracks_name', 'artists_id', 'artists_name', 'album_id', 'uri', 'preview_url', 'country', 'lyrics']]

drop_columns()

# %%
pd.set_option('display.max_columns', None)
df_artists_tracks.head(5)
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness   key  \
# 0         0.294         0.698     235584.0   0.606          0.000003  10.0
# 1         0.166         0.543     233998.0   0.612          0.000000   9.0
# 2         0.863         0.719     656960.0   0.308          0.000000   6.0
# 3         0.824         0.688      29240.0   0.304          0.000000  10.0
# 4         0.850         0.632     497493.0   0.372          0.000000   7.0
#
#    liveness  loudness  mode  popularity  speechiness    tempo  time_signature  \
# 0     0.151    -7.447   0.0        28.0       0.0262  115.018             4.0
# 1     0.129    -7.685   0.0        37.0       0.0487  139.876             3.0
# 2     0.253   -10.340   1.0        31.0       0.9220  115.075             3.0
# 3     0.142    -9.960   1.0         0.0       0.5310   77.056             3.0
# 4     0.110    -8.760   1.0        30.0       0.9350   84.486             4.0
#
#    valence  artist_popularity  followers             genres  \
# 0    0.622                 28        425  ['finnish indie']
# 1    0.463                 28        425  ['finnish indie']
# 2    0.589                 36       2965                 []
# 3    0.414                 36       2965                 []
# 4    0.611                 36       2965                 []
#
#                 tracks_id                  tracks_name  \
# 0  5qljLQuKnNJf4F4vfxQB0V                        Blood
# 1  3THTkAwJOsmxgizvYkBNRI                      Jericho
# 2  3VAX2MJdmdqARLSU5hPMpm            The Ugly Duckling
# 3  1WJzRtI1ABzV3TPIeJZVvi             Three Blind Mice
# 4  65MopnhsXOgYw4RuiA2pGU  The Three Billy Goats Gruff
#
#                artists_id           artists_name                album_id  \
# 0  3mxJuHRn2ZWD5OofvJtDZY           Jesse Markin  0D3QufeCudpQANOR7luqdr
# 1  3mxJuHRn2ZWD5OofvJtDZY           Jesse Markin  3wIjGVauUxR4c3NvnQZ0Jo
# 2  4xWMewm6CYMstu0sPgd9jJ  Favorite Kids Stories  1bcqsH5UyTBzmh9YizdsBE
# 3  4xWMewm6CYMstu0sPgd9jJ  Favorite Kids Stories  51g5viCaYjOW5XO4qX1RCD
# 4  4xWMewm6CYMstu0sPgd9jJ  Favorite Kids Stories  7EtGJVYZbb2Krgwizn2flB
#
#                                     uri  \
# 0  spotify:track:5qljLQuKnNJf4F4vfxQB0V
# 1  spotify:track:3THTkAwJOsmxgizvYkBNRI
# 2  spotify:track:3VAX2MJdmdqARLSU5hPMpm
# 3  spotify:track:1WJzRtI1ABzV3TPIeJZVvi
# 4  spotify:track:65MopnhsXOgYw4RuiA2pGU
#
#                                          preview_url country  \
# 0  https://p.scdn.co/mp3-preview/1b05a902da3a251d...      BE
# 1  https://p.scdn.co/mp3-preview/8af517b8202114d6...      AR
# 2  https://p.scdn.co/mp3-preview/d8140736a6131cb5...      BE
# 3  https://p.scdn.co/mp3-preview/54031f6d3ab4784a...      BE
# 4  https://p.scdn.co/mp3-preview/32c98e55e89da792...      BE
#
#                                               lyrics
# 0  \r\n\r\nPerhaps I am bound to be restless\r\nA...
# 1  \r\n\r\nMuch better in my day\r\nMuch better i...
# 2  \r\nYour Gods and my Gods-do you or I know whi...
# 3  \r\nYour Gods and my Gods-do you or I know whi...
# 4  \r\nYour Gods and my Gods-do you or I know whi...

# %% [markdown]
# ## Data Preprocessing

# %%
# No empty values
df_artists_tracks.isna().sum()
# Out:
# acousticness         0
# danceability         0
# duration_ms          0
# energy               0
# instrumentalness     0
# key                  0
# liveness             0
# loudness             0
# mode                 0
# popularity           0
# speechiness          0
# tempo                0
# time_signature       0
# valence              0
# artist_popularity    0
# followers            0
# genres               0
# tracks_id            0
# tracks_name          0
# artists_id           0
# artists_name         0
# album_id             0
# uri                  0
# preview_url          0
# country              0
# lyrics               0
# dtype: int64

# %% [markdown]
# ### Processing Genre

# %%
df_artists_tracks['genres'].unique()
# Out:
# array(["['finnish indie']", '[]', "['british comedy', 'comedy']", ...,
#        "['electronic', 'nu skool breaks', 'progressive house', 'progressive trance', 'progressive trance house', 'trance', 'uplifting trance']",
#        "['icelandic hip hop']",
#        "['australian alternative rock', 'australian indie', 'australian pop', 'australian rock', 'perth indie']"],
#       dtype=object)

# %%
df_artists_tracks['genres'].unique()

# count the number of genres
df_artists_tracks['genres'].nunique()
# Out:
# 10728

# %%
df_artists_tracks['genres']
# Out:
# 0                                        ['finnish indie']
# 1                                        ['finnish indie']
# 2                                                       []
# 3                                                       []
# 4                                                       []
#                                ...
# 77840                                     ['chilean rock']
# 77841                                 ['scandinavian r&b']
# 77842                                ['icelandic hip hop']
# 77843    ['australian alternative rock', 'australian in...
# 77844    ['australian alternative rock', 'australian in...
# Name: genres, Length: 77845, dtype: object

# %%
print(df_artists_tracks[df_artists_tracks['genres'] == '[]']['genres'].count())
df_artists_tracks[df_artists_tracks['genres'] != '[]']['genres'].count()
# Out:
# 15142
# 62703

# %%
genre_counts = df_artists_tracks['genres'].apply(eval).explode().value_counts()
print(genre_counts)
# Out:
# pop                       3553
# dance pop                 2587
# rock                      2572
# folk-pop                  2149
# latin                     2116
#                           ...
# house argentino              1
# unblack metal                1
# musica folk asturiana        1
# early modern classical       1
# icelandic hip hop            1
# Name: genres, Length: 2260, dtype: int64

# %%
genre_counts[genre_counts > 500]
#genre_counts[:10]
# Out:
# pop                 3553
# dance pop           2587
# rock                2572
# folk-pop            2149
# latin               2116
#                     ...
# israeli pop          508
# indie cafe pop       504
# kleine hoerspiel     503
# spanish pop          501
# anthem worship       501
# Name: genres, Length: 98, dtype: int64
